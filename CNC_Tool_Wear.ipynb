# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemanthk408/CNC_Tool/blob/main/CNC_Tool_Wear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd

# Folder containing CSV files
csv_folder = "/content/drive/MyDrive/CNC Experiments Files"  # Change this path

# List all CSV files in the folder
csv_files = [f for f in os.listdir(csv_folder) if f.endswith('.csv')]

# Create an empty DataFrame to store merged data
merged_df = pd.DataFrame()

# Loop through each CSV file and append to the DataFrame
for file in csv_files:
    file_path = os.path.join(csv_folder, file)
    df = pd.read_csv(file_path)  # Read CSV
    merged_df = pd.concat([merged_df, df], ignore_index=True)  # Merge

# Save the merged file
output_file = os.path.join(csv_folder, "merged_output.csv")
merged_df.to_csv(output_file, index=False)

print(f"Merged {len(csv_files)} CSV files into {output_file}")
# Out:
# Merged 19 CSV files into /content/drive/MyDrive/CNC Experiments Files/merged_output.csv

# %%
ex1=pd.read_csv("/content/drive/MyDrive/CNC Experiments Files/experiment_01.csv")
ex1
# Out:
#       X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0                 198.0              0.000                   0.00
# 1                 198.0            -10.800                -350.00
# 2                 196.0            -17.800                  -6.25
# 3                 194.0            -18.000                   0.00
# 4                 193.0            -17.900                 -18.80
# ...                 ...                ...                    ...
# 1050              141.0              0.175                  87.50
# 1051              141.0             -0.150                 -87.50
# 1052              141.0             -0.175                 -87.50
# 1053              141.0              0.150                  87.50
# 1054              141.0              0.175                  93.70
#
#       X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0                  198.0                 0.0                0.000000
# ...

# %%
df=pd.read_csv("/content/drive/MyDrive/CNC Experiments Files/merged_output.csv")

# %%
df.to_csv("CNC_Merged_data.csv")

# %%
df
# Out:
#        X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0                  198.0               0.00                   0.00
# 1                  198.0             -10.80                -350.00
# 2                  196.0             -17.80                  -6.25
# 3                  194.0             -18.00                   0.00
# 4                  193.0             -17.90                 -18.80
# ...                  ...                ...                    ...
# 75853              144.0              -2.30                 100.00
# 75854              144.0              -2.47                  25.00
# 75855              143.0              -2.20                  81.20
# 75856              143.0              -2.05                  68.70
# 75857              143.0              -2.15                 -68.70
#
#        X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0                   198.0                0.00                0.000000
# ...

# %%
df.isnull().sum()
# Out:
# X1_ActualPosition            0
# X1_ActualVelocity            0
# X1_ActualAcceleration        0
# X1_CommandPosition           0
# X1_CommandVelocity           0
# X1_CommandAcceleration       0
# X1_CurrentFeedback           0
# X1_DCBusVoltage              0
# X1_OutputCurrent             0
# X1_OutputVoltage             0
# X1_OutputPower               0
# Y1_ActualPosition            0
# Y1_ActualVelocity            0
# Y1_ActualAcceleration        0
# Y1_CommandPosition           0
# Y1_CommandVelocity           0
# Y1_CommandAcceleration       0
# Y1_CurrentFeedback           0
# Y1_DCBusVoltage              0
# Y1_OutputCurrent             0
# Y1_OutputVoltage             0
# Y1_OutputPower               0
# Z1_ActualPosition            0
# Z1_ActualVelocity            0
# Z1_ActualAcceleration        0
# Z1_CommandPosition           0
# Z1_CommandVelocity           0
# Z1_CommandAcceleration       0
# Z1_CurrentFeedback           0
# Z1_DCBusVoltage              0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
pd.set_option("display.max_columns",None)

# %%
df
# Out:
#        X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0                  198.0               0.00                   0.00
# 1                  198.0             -10.80                -350.00
# 2                  196.0             -17.80                  -6.25
# 3                  194.0             -18.00                   0.00
# 4                  193.0             -17.90                 -18.80
# ...                  ...                ...                    ...
# 25281              144.0              -2.30                 100.00
# 25282              144.0              -2.47                  25.00
# 25283              143.0              -2.20                  81.20
# 25284              143.0              -2.05                  68.70
# 25285              143.0              -2.15                 -68.70
#
#        X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0                   198.0                0.00                0.000000
# ...

# %%
df.nunique().sort_values()
# Out:
# S1_SystemInertia                1
# Z1_OutputVoltage                1
# Z1_OutputCurrent                1
# Z1_DCBusVoltage                 1
# Z1_CurrentFeedback              1
# M1_CURRENT_PROGRAM_NUMBER       3
# S1_CommandAcceleration          5
# M1_CURRENT_FEEDRATE             6
# Machining_Process              11
# X1_OutputCurrent               12
# Y1_OutputCurrent               15
# Z1_CommandAcceleration         31
# S1_OutputCurrent               38
# X1_ActualPosition              58
# X1_CommandPosition             58
# Z1_CommandVelocity             74
# S1_CommandVelocity             75
# S1_OutputVoltage              125
# M1_sequence_number            135
# Z1_ActualAcceleration         177
# Z1_ActualVelocity             244
# X1_ActualAcceleration         259
# Y1_ActualAcceleration         264
# Y1_CommandPosition            335
# Y1_ActualPosition             335
# S1_ActualVelocity             368
# Z1_ActualPosition             474
# ...

# %%
df.nunique().sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-b156c954e232> in <cell line: 0>()
# ----> 1 df.nunique().sort()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'sort'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24955 entries, 0 to 25285
# Data columns (total 48 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   X1_ActualPosition          24955 non-null  float64
#  1   X1_ActualVelocity          24955 non-null  float64
#  2   X1_ActualAcceleration      24955 non-null  float64
#  3   X1_CommandPosition         24955 non-null  float64
#  4   X1_CommandVelocity         24955 non-null  float64
#  5   X1_CommandAcceleration     24955 non-null  float64
#  6   X1_CurrentFeedback         24955 non-null  float64
#  7   X1_DCBusVoltage            24955 non-null  float64
#  8   X1_OutputCurrent           24955 non-null  float64
#  9   X1_OutputVoltage           24955 non-null  float64
#  10  X1_OutputPower             24955 non-null  float64
#  11  Y1_ActualPosition          24955 non-null  float64
#  12  Y1_ActualVelocity          24955 non-null  float64
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
encoder=OrdinalEncoder()

# %%
df["Machining_Process"]=encoder.fit_transform(df[["Machining_Process"]])

# %%
df.corr()
# Out:
#                            X1_ActualPosition  X1_ActualVelocity  \
# X1_ActualPosition                   1.000000          -0.030053
# X1_ActualVelocity                  -0.030053           1.000000
# X1_ActualAcceleration              -0.016814           0.042901
# X1_CommandPosition                  0.999891          -0.027657
# X1_CommandVelocity                 -0.032363           0.994735
# X1_CommandAcceleration             -0.023258          -0.054833
# X1_CurrentFeedback                  0.077991           0.656778
# X1_DCBusVoltage                    -0.507095          -0.007060
# X1_OutputCurrent                    0.338770          -0.058275
# X1_OutputVoltage                   -0.274170           0.064618
# X1_OutputPower                     -0.072595           0.190481
# Y1_ActualPosition                   0.882261           0.011645
# Y1_ActualVelocity                  -0.107476           0.296452
# Y1_ActualAcceleration              -0.006810          -0.013733
# ...
